# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 取出今天所有的發文
# * ② 如果想要依照類別分類，怎麼儲存會比較好？
# * ③ 哪一個類別的文章最多

# %% [markdown]
# ### ① 取出今天所有的發文

# %%
import requests
import datetime
import re
import pandas as pd
from bs4 import BeautifulSoup

columns = ['日期', '類別', '標題']

url = 'https://www.ettoday.net/news/news-list.htm'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

# %%
pattern ='[0-9]{4}(?:/[0-9]{2}){2}'
today = datetime.date.today().strftime("%Y/%m/%d")

articles = []

for d in soup.find(class_="part_list_2").find_all('h3'):
    if re.match(pattern, d.find(class_="date").text)[0] == today:
        print(d.find(class_="date").text, d.find_all('a')[-1].text)
        articles.append([d.find(class_="date").text, d.find('em').text, d.find_all('a')[-1].text])
# Out:
# 2019/12/22 01:50 企聯女壘／新世紀黃蜂奪冠大贏家　美洋投卡爾森獲年度MVP
# 2019/12/22 01:42 《超人》5獎成KBS演藝大賞最大贏家！驚喜宣布：建厚要當哥哥了
# 2019/12/22 01:37 結算2019年「造人績效」全球人口達77.5億　一年生出「一個德國」人口
# 2019/12/22 01:10 解放軍「駐澳門部隊」首次編入反恐方隊　換裝「星空迷彩」接受習近平檢閱
# 2019/12/22 00:58 85萬人高雄遊行！尹立5天後「提交罷韓連署」…韓辦關鍵分析打臉
# 2019/12/22 00:58 波音「星際飛機」首航失敗！被迫提早返回地球　NASA曝關鍵原因
# 2019/12/22 00:41 臉書揭穿史上最大假帳號集團　廣告金額是俄羅斯網軍的「100倍」
# 2019/12/22 00:38 章子怡悄赴加州待產！　天價產子費用「一胎40萬」…貝克漢愛女也在這出生
# 2019/12/22 00:37 2019「海安耶誕PARTY」熱鬧登場　黃偉哲祝市民朋友耶誕快樂
# 2019/12/22 00:31 出門補妝好麻煩？彩妝手機殼眼影、口紅全都有　一盒帶著超方便
# 2019/12/22 00:27 台南好young耶誕跨年演唱會嗨翻天　黃偉哲與市民同歡
# 2019/12/22 00:26 睜眼發現被性侵！酒店妹喝醉「電梯內被扶走」痛醒崩潰
# 2019/12/22 00:23 空拍超震撼！5萬人塞滿凱道　蔡英文「撩選民」力挺林昶佐：2020台灣大凱旋
# 2019/12/22 00:13 香蕉哥哥當爸！　見兒子小新出生「眼眶濕了」：這是全世界最棒的聖誕禮物
# 2019/12/22 00:13 手機比小孩重要！11歲男童上節目爆哭：多陪陪我好不好…
# 2019/12/22 00:10 蠟燭燒完，2步驟清理法必學！讓漂亮蠟燭杯成為超有品味的居家裝飾
# 2019/12/22 00:06 陳菊欠債3千億躲中央　議員諷：是光復高雄還是「花光高雄」？
# 2019/12/22 00:05 韓國瑜底氣十足！地方人士：2020是「庶民藍」與「權貴綠」之爭
# 2019/12/22 00:05 YAMAHA CUP／張仟縈高度肯定　石牌沈芮恩無懼和男生衝撞
# 2019/12/22 00:03 張善政先批蔡英文「沒生小孩」、再譏友邦「助益小」 網友：H病毒好可怕
# 2019/12/22 00:03 陰道整型迷思大破解　雷射手術「撫平皺摺」更性福？
# 2019/12/22 00:00 韓國瑜：高雄百年來沒有像此刻如巨星般冉冉崛起

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
df = pd.DataFrame(articles, columns=columns)
df
# Out:
#                   日期  類別                                     標題
# 0   2019/12/22 01:50  體育           企聯女壘／新世紀黃蜂奪冠大贏家　美洋投卡爾森獲年度MVP
# 1   2019/12/22 01:42  影劇        《超人》5獎成KBS演藝大賞最大贏家！驚喜宣布：建厚要當哥哥了
# 2   2019/12/22 01:37  國際   結算2019年「造人績效」全球人口達77.5億　一年生出「一個德國」人口
# 3   2019/12/22 01:10  軍武     解放軍「駐澳門部隊」首次編入反恐方隊　換裝「星空迷彩」接受習近平檢閱
# 4   2019/12/22 00:58  政治        85萬人高雄遊行！尹立5天後「提交罷韓連署」…韓辦關鍵分析打臉
# 5   2019/12/22 00:58  國際        波音「星際飛機」首航失敗！被迫提早返回地球　NASA曝關鍵原因
# 6   2019/12/22 00:41  國際        臉書揭穿史上最大假帳號集團　廣告金額是俄羅斯網軍的「100倍」
# 7   2019/12/22 00:38  影劇    章子怡悄赴加州待產！　天價產子費用「一胎40萬」…貝克漢愛女也在這出生
# 8   2019/12/22 00:37  地方       2019「海安耶誕PARTY」熱鬧登場　黃偉哲祝市民朋友耶誕快樂
# 9   2019/12/22 00:31  時尚          出門補妝好麻煩？彩妝手機殼眼影、口紅全都有　一盒帶著超方便
# 10  2019/12/22 00:27  生活            台南好young耶誕跨年演唱會嗨翻天　黃偉哲與市民同歡
# 11  2019/12/22 00:26  社會              睜眼發現被性侵！酒店妹喝醉「電梯內被扶走」痛醒崩潰
# 12  2019/12/22 00:23  政治  空拍超震撼！5萬人塞滿凱道　蔡英文「撩選民」力挺林昶佐：2020台灣大凱旋
# 13  2019/12/22 00:13  影劇     香蕉哥哥當爸！　見兒子小新出生「眼眶濕了」：這是全世界最棒的聖誕禮物
# 14  2019/12/22 00:13  大陸            手機比小孩重要！11歲男童上節目爆哭：多陪陪我好不好…
# 15  2019/12/22 00:10  時尚        蠟燭燒完，2步驟清理法必學！讓漂亮蠟燭杯成為超有品味的居家裝飾
# 16  2019/12/22 00:06  政治          陳菊欠債3千億躲中央　議員諷：是光復高雄還是「花光高雄」？
# 17  2019/12/22 00:05  政治        韓國瑜底氣十足！地方人士：2020是「庶民藍」與「權貴綠」之爭
# 18  2019/12/22 00:05  體育        YAMAHA CUP／張仟縈高度肯定　石牌沈芮恩無懼和男生衝撞
# 19  2019/12/22 00:03  政治     張善政先批蔡英文「沒生小孩」、再譏友邦「助益小」 網友：H病毒好可怕
# 20  2019/12/22 00:03  健康               陰道整型迷思大破解　雷射手術「撫平皺摺」更性福？
# 21  2019/12/22 00:00  政治                 韓國瑜：高雄百年來沒有像此刻如巨星般冉冉崛起

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
group = df.groupby('類別')
group.groups
# Out:
# {'健康': Int64Index([20], dtype='int64'),
#  '國際': Int64Index([2, 5, 6], dtype='int64'),
#  '地方': Int64Index([8], dtype='int64'),
#  '大陸': Int64Index([14], dtype='int64'),
#  '影劇': Int64Index([1, 7, 13], dtype='int64'),
#  '政治': Int64Index([4, 12, 16, 17, 19, 21], dtype='int64'),
#  '時尚': Int64Index([9, 15], dtype='int64'),
#  '生活': Int64Index([10], dtype='int64'),
#  '社會': Int64Index([11], dtype='int64'),
#  '軍武': Int64Index([3], dtype='int64'),
#  '體育': Int64Index([0, 18], dtype='int64')}

# %%
df2 = pd.DataFrame(df.groupby('類別').size(), columns=['文章數量'])
df2['排名'] = df2.rank(method='min', ascending=False)
df2.sort_values(by=['排名'])
# Out:
#     文章數量   排名
# 類別
# 政治     6  1.0
# 國際     3  2.0
# 影劇     3  2.0
# 時尚     2  4.0
# 體育     2  4.0
# 健康     1  6.0
# 地方     1  6.0
# 大陸     1  6.0
# 生活     1  6.0
# 社會     1  6.0
# 軍武     1  6.0
